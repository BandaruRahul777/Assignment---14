# %%
Question 1

# %%
RGBA color values are an extension of RGB color values with an alpha channel - which specifies the opacity for a color.
An RGBA color value is specified with: rgba(red, green, blue, alpha).

# %%
Question 2

# %%
Pillow offers the ImageColor. getcolor() function so you don't have to memorize RGBA values for the colors you want to use.
This function takes a color name string as its first argument, and the string 'RGBA' as its second argument, and it returns an
RGBA tuple.

# %%
Question 3

# %%
A box tuple is a tuple value of four integers: the left-edge x-coordinate, the top-edge y-coordinate, the width, and the height.

# %%
Question 4

# %%
img.size is a tuple of two integers, the width and the height.

# %% [markdown]
# ![image.jpg.jpg](attachment:image.jpg.jpg)

# %%
Question 5

# %%
img.crop((0, 50, 50, 50)) #Notice that you are passing a box tuple to crop(), not four separate integer arguments.

# %%
Question 6

# %%
Question 7

# %%
The ImageDraw module contains code to draw on images.

# %%
Question 8

# %%
ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle(). They are returned by passing the Image
object to the ImageDraw.Draw() function.
